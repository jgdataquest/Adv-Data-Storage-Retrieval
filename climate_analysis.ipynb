# %%
from sqlalchemy import create_engine, Table, Column, MetaData
from sqlalchemy.orm import mapper, create_session
from sqlalchemy.ext.declarative import declarative_base
from pandas.io.sql import SQLTable, SQLDatabase
from sqlalchemy import create_engine
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
engine = create_engine('mysql://jg_dba:jg_dba@localhost/hawaii', echo=False)

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['measurements', 'stations']

# %%
measurements = Base.classes.measurements
stations = Base.classes.stations
session = Session(engine)

# %%
import pandas as pd
df = pd.read_sql_query("SELECT date, prcp FROM measurements", engine)
df.head()
# Out:
#          date  prcp
# 0  2010-01-01  0.08
# 1  2010-01-02  0.00
# 2  2010-01-03  0.00
# 3  2010-01-04  0.00
# 4  2010-01-06 -0.01

# %%
df[df['date'].str.contains("2016|2017")]
# Out:
#              date  prcp
# 2128   2016-01-01  0.00
# 2129   2016-01-02  0.00
# 2130   2016-01-03  0.00
# 2131   2016-01-04  0.00
# 2132   2016-01-05  0.00
# 2133   2016-01-06  0.00
# 2134   2016-01-07  0.18
# 2135   2016-01-08  0.01
# 2136   2016-01-09  0.03
# 2137   2016-01-10  0.01
# 2138   2016-01-11  0.00
# 2139   2016-01-12  0.00
# 2140   2016-01-13  0.00
# 2141   2016-01-14  0.00
# 2142   2016-01-15  0.00
# 2143   2016-01-16  0.01
# 2144   2016-01-17  0.00
# 2145   2016-01-18  0.00
# 2146   2016-01-19  0.00
# 2147   2016-01-20  0.00
# 2148   2016-01-21  0.00
# 2149   2016-01-22  0.00
# 2150   2016-01-23  0.00
# 2151   2016-01-24  0.00
# 2152   2016-01-25  0.04
# 2153   2016-01-26  0.16
# 2154   2016-01-27  0.01
# 2155   2016-01-28  0.00
# 2156   2016-01-29  0.00
# 2157   2016-01-30  0.00
# ...           ...   ...
# 19520  2017-07-24  0.84
# 19521  2017-07-25  0.30
# 19522  2017-07-26  0.30
# 19523  2017-07-27  0.00
# 19524  2017-07-28  0.40
# 19525  2017-07-29  0.30
# ...

# %%
import datetime
import time
now = datetime.datetime.now()
last_year = now.year -1
month = now.month
day = now.day
# Out:
# 2016
